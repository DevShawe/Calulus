# %%
import sympy as sp
x = sp.Symbol('x')
sp.diff(x**3)
# Out:
# 3*x**2

# %%
sp.plot(sp.diff(x**3))

# %%
sp.diff(x**3,x,x)
# Out:
# 6*x

# %%
sp.diff(sp.sin(x)*(2*x**2+2))
# Out:
# 4*x*sin(x) + (2*x**2 + 2)*cos(x)

# %%
sp.diff((sp.sin(x))/x)
# Out:
# cos(x)/x - sin(x)/x**2

# %%
sp.diff((x**2+1)**7)
# Out:
# 14*x*(x**2 + 1)**6
